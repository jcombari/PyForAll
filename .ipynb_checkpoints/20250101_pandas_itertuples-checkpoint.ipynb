# %% [markdown]
# # 🐼 Python-Pandas: The best-kept secret for iterating rows like a pro
#
# Did you know there’s a faster and more efficient way to iterate through rows in Pandas without using `iterrows`? 🚀
#
# 📊 **Common scenario:** You’re analyzing a dataset and need to process each row individually. Your first instinct might be to use `iterrows`, but this method can be slow and resource-intensive. Enter `itertuples`, an underrated alternative. 🧠
#
# 👇 **Why choose itertuples?**
# - 🔥 Up to 30% faster than `iterrows`.
# - 📦 Returns a tuple-like object, improving performance.
# - 💡 Perfect for tasks like summing values or calculating metrics row by row in large datasets.
#
# ✨ **Practical example:** Let’s use Seaborn’s classic Titanic dataset to compute the average fare spent by passengers per class, processing it row by row.
#
# 💡 **Impact in data science:**
# ✔️ Optimizes performance in repetitive tasks.
# ✔️ Handles massive datasets without sacrificing time or efficiency.
# ✔️ A practical solution for custom calculations.
#
# 🎯 **In real-world scenarios:**
# 👉 Imagine calculating customer-specific metrics in a sales dataset with millions of records. `itertuples` can get the job done faster.
#
# 🌍 **How would you enhance your analysis using this technique?**
#
# 🚀 Keep exploring new tricks with Pandas and elevate your data science toolkit.
#
# [Discover more on GitHub](https://github.com/jcombari/PyForAll)
#
# #️⃣ #pandas #datascience #python #machinelearning #dataanalysis #ai #deeplearning #bigdata
#
# ---
# # 🐼 Python-Pandas: El secreto mejor guardado para iterar filas como un profesional
#
# ¿Sabías que hay una forma más rápida y eficiente de recorrer filas en Pandas sin usar iterrows? 🚀
#
# 📊 Historia común: Estás analizando un dataset y necesitas procesar cada fila individualmente. El primer instinto es usar `iterrows`, pero este método puede ser lento y consumir muchos recursos. Aquí es donde entra `itertuples`, la alternativa que muchos subestiman. 🧠
#
# 👇 **¿Por qué elegir itertuples?**
# - 🔥 Hasta 30% más rápido que `iterrows`.
# - 📦 Devuelve un objeto tipo tupla, lo que mejora el rendimiento.
# - 💡 Ideal para tareas como sumar valores o calcular métricas fila por fila en datasets grandes.
#
# ✨ **Ejemplo práctico:** Procesemos el clásico dataset titanic de Seaborn para calcular el gasto promedio de pasajeros por clase, pero lo haremos fila por fila.
#
# 💡 **Impacto en la ciencia de datos:**
# ✔️ Optimiza el rendimiento en tareas repetitivas.
# ✔️ Trabaja con datasets masivos sin sacrificar tiempo ni eficiencia.
# ✔️ Una solución práctica para cálculos personalizados.
#
# 🎯 **En el mundo real:**
# 👉 Imagina que necesitas calcular métricas personalizadas por cliente en un dataset de ventas de millones de registros. `itertuples` hará el trabajo más rápido.
#
# 🌍 **¿Cómo mejorarías tus análisis con esta técnica?**
#
# 🚀 Sigue explorando nuevos trucos con Pandas y potencia tu toolkit de ciencia de datos.
#
# [Descubre más en GitHub](https://github.com/jcombari/PyForAll)
#
# #️⃣ #pandas #datascience #python #machinelearning #dataanalysis #ai #deeplearning #bigdata

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns

# Load the Titanic dataset
titanic = sns.load_dataset('titanic')

# Display basic information about the dataset
print(titanic.info())  # View column data types and non-null counts
print(titanic.head())  # Preview the first 5 rows of the dataset

# Group passengers by class and calculate average fare using `itertuples`
# Prepare an empty dictionary to store results
class_fare = {}

# Iterate through rows using itertuples
for row in titanic.itertuples(index=False):
    # Access 'pclass' and 'fare' attributes
    if row.pclass not in class_fare:
        class_fare[row.pclass] = []
    class_fare[row.pclass].append(row.fare)

# Compute the average fare for each class
average_fare = {key: sum(values) / len(values) for key, values in class_fare.items()}

# Display the results
print("\nAverage Fare per Class:")
for pclass, avg_fare in average_fare.items():
    print(f"Class {pclass}: ${avg_fare:.2f}")

# Example output visualization
import matplotlib.pyplot as plt

# Plot the average fare per class
classes = list(average_fare.keys())
fares = list(average_fare.values())

plt.bar(classes, fares, color=['blue', 'green', 'red'])
plt.title('Average Fare by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Average Fare')
plt.xticks(classes, labels=['1st Class', '2nd Class', '3rd Class'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None
# ...
