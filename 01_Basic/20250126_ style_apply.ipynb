# %% [markdown]
# # ✨ 🐍🐼 Python-Pandas | Become the Master of Dates! ✨
#
# ### ❓ Did you know dates can be your secret weapon for analyzing temporal data?
# 🙃 With Pandas' advanced functions, you can turn dates into powerful insights, like identifying weekdays, flagging weekends automatically, or calculating time differences in months.
#
# ### 🔧 How does it work?
# Pandas provides the `.dt` attribute to extract and manipulate date components like days, weeks, months, years, and even whether it's a weekend.
#
# ### 🔎 Why does it matter?
# In a data-driven world, mastering dates can mean the difference between surface-level analysis and solving complex business problems. From forecasting sales to campaign planning, dates give you context and depth.
#
# ### ✨ Real-world example:
# Imagine you're part of a marketing team analyzing how weekends impact website traffic. With Pandas, you can:
# - 🗓️ Automatically flag weekends in your dataset.
# - 📉 Calculate the time elapsed between two key events.
# - 🔍 Filter weekdays to optimize your strategies.
#
# ### ⚙️ Business impact:
# These tools help uncover hidden patterns in data, such as user behavior during specific campaigns, improving decision-making and maximizing return on investment (ROI).
#
# ### 📊 Summary of the example in the code:
# - We'll use the `pd.date_range()` function to generate a range of dates in the year 2025, create a dataset, and explore:
#   - Extracting weekdays.
#   - Calculating time differences in months.
#   - Creating new columns to flag weekends.
#
# ### 💭 Reflection:
# Temporal data is everywhere. How could you use these techniques to transform your daily analysis?
#
# 🌍✨ **#Python #Pandas #DataScience #MachineLearning #GenerativeAI #DataVisualization #DeepLearning #AIForGood #Mentorship #DataScienceCommunity**
#
# 🔗 [Code on GitHub](https://github.com/jcombari/PyForAll/blob/main/20250126_%20style_apply.ipynb)
#
# ---
#
# # ✨ 🐍🐼 Python-Pandas | ¡Conviértete en el maestro de las fechas! ✨
#
# ### ❓ ¿Sabías que las fechas pueden ser tu mejor herramienta para analizar datos temporales?
# 🙃 Con las funciones avanzadas de Pandas, puedes transformar fechas en poderosos insights, como identificar días laborales, marcar automáticamente fines de semana o calcular diferencias de tiempo en meses.
#
# ### 🔧 ¿Cómo funciona?
# Pandas incluye el atributo `.dt` para extraer y manipular componentes de fechas como días, semanas, meses, años, e incluso si es fin de semana.
#
# ### 🔎 ¿Por qué importa?
# En un mundo impulsado por datos, saber cómo manejar fechas puede marcar la diferencia entre un análisis superficial y uno que resuelve problemas de negocio. Desde predicciones de ventas hasta la planificación de campañas, las fechas te dan contexto y profundidad.
#
# ### ✨ Ejemplo real o caso práctico:
# Imagina que trabajas en un equipo de marketing para analizar cómo los fines de semana impactan en el tráfico del sitio web. Usando Pandas, puedes:
# - 🗓️ Identificar automáticamente fines de semana en tu dataset.
# - 📉 Calcular cuánto tiempo transcurre entre dos eventos clave.
# - 🔍 Filtrar días laborales para optimizar tus estrategias.
#
# ### ⚙️ Impacto en el negocio:
# Estas herramientas te permiten identificar patrones ocultos en los datos, como el comportamiento de los usuarios durante campañas específicas, mejorando la toma de decisiones y maximizando el retorno de inversión (ROI).
#
# ### 📊 Resumen del ejemplo en el código:
# - Usaremos la función `pd.date_range()` para generar un rango de fechas en el año 2025, crear un dataset y explorar:
#   - Extracción de días de la semana.
#   - Cálculo de diferencias en meses.
#   - Creación de nuevas columnas que marquen fines de semana.
#
# ### 💭 Reflexión:
# Los datos temporales están en todas partes. ¿Cómo podrías usar estas técnicas para transformar tus análisis diarios?
#
# 🌍✨ **#Python #Pandas #DataScience #MachineLearning #GenerativeAI #DataVisualization #DeepLearning #AIForGood #Mentoría #CienciaDeDatos**
#
# 🔗 [Código en GitHub](https://github.com/jcombari/PyForAll/blob/main/20250126_%20style_apply.ipynb)

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import numpy as np

# Load a sample dataset
df = sns.load_dataset('titanic')

# Filter only relevant columns for simplicity
df = df[['survived', 'pclass', 'age']].dropna()

# Normalize the 'age' column to create a range from 0 to 1
min_age, max_age = df['age'].min(), df['age'].max()
df['normalized_age'] = (df['age'] - min_age) / (max_age - min_age)

# Define a function to map normalized values to a color gradient
def age_to_color(normalized_value):
    """
    Maps a normalized value (0 to 1) to a color gradient.
    Green for low values, red for high values, with yellow and orange in between.
    """
    # Define the color palette (Excel-style gradient: green -> yellow -> red)
    color_gradient = sns.color_palette("RdYlGn", as_cmap=True)
    # Map the normalized value to the gradient
    rgba = color_gradient(normalized_value)
    # Convert RGBA to hexadecimal for styling
    return f"background-color: rgba({int(rgba[0]*255)}, {int(rgba[1]*255)}, {int(rgba[2]*255)}, 0.7);"

# Apply the color gradient to the 'age' column
styled_df = df.style.map(lambda v: age_to_color(v), subset=['normalized_age'])

# Save styled DataFrame as an HTML file for a polished presentation
styled_df.to_html("styled_titanic_age.html")

# Display the styled DataFrame directly (for Jupyter Notebook)
styled_df
# Out:
# <style type="text/css">
# #T_f1040_row0_col3, #T_f1040_row45_col3, #T_f1040_row61_col3, #T_f1040_row87_col3, #T_f1040_row112_col3, #T_f1040_row122_col3, #T_f1040_row170_col3, #T_f1040_row181_col3, #T_f1040_row195_col3, #T_f1040_row231_col3, #T_f1040_row233_col3, #T_f1040_row257_col3, #T_f1040_row260_col3, #T_f1040_row286_col3, #T_f1040_row298_col3, #T_f1040_row300_col3, #T_f1040_row317_col3, #T_f1040_row378_col3, #T_f1040_row381_col3, #T_f1040_row415_col3, #T_f1040_row427_col3, #T_f1040_row439_col3, #T_f1040_row440_col3, #T_f1040_row466_col3, #T_f1040_row480_col3, #T_f1040_row563_col3, #T_f1040_row706_col3 {
#   background-color: rgba(250, 154, 88, 0.7);
# }
# #T_f1040_row1_col3, #T_f1040_row22_col3, #T_f1040_row46_col3, #T_f1040_row84_col3, #T_f1040_row180_col3, #T_f1040_row267_col3, #T_f1040_row287_col3, #T_f1040_row372_col3, #T_f1040_row375_col3, #T_f1040_row569_col3, #T_f1040_row658_col3 {
#   background-color: rgba(254, 245, 175, 0.7);
# }
# #T_f1040_row2_col3, #T_f1040_row52_col3, #T_f1040_row56_col3, #T_f1040_row72_col3, #T_f1040_row130_col3, #T_f1040_row165_col3, #T_f1040_row234_col3, #T_f1040_row249_col3, #T_f1040_row252_col3, #T_f1040_row323_col3, #T_f1040_row405_col3, #T_f1040_row486_col3, #T_f1040_row488_col3, #T_f1040_row497_col3, #T_f1040_row559_col3, #T_f1040_row647_col3, #T_f1040_row695_col3, #T_f1040_row712_col3 {
#   background-color: rgba(253, 184, 106, 0.7);
# }
# #T_f1040_row3_col3, #T_f1040_row4_col3, #T_f1040_row17_col3, #T_f1040_row169_col3, #T_f1040_row185_col3, #T_f1040_row208_col3, #T_f1040_row217_col3, #T_f1040_row224_col3, #T_f1040_row291_col3, #T_f1040_row307_col3, #T_f1040_row387_col3, #T_f1040_row467_col3, #T_f1040_row476_col3, #T_f1040_row483_col3, #T_f1040_row556_col3, #T_f1040_row587_col3, #T_f1040_row649_col3, #T_f1040_row676_col3 {
#   background-color: rgba(254, 234, 157, 0.7);
# }
# #T_f1040_row5_col3, #T_f1040_row98_col3, #T_f1040_row201_col3, #T_f1040_row254_col3, #T_f1040_row395_col3, #T_f1040_row408_col3, #T_f1040_row461_col3, #T_f1040_row617_col3 {
#   background-color: rgba(179, 222, 114, 0.7);
# }
# #T_f1040_row6_col3, #T_f1040_row15_col3, #T_f1040_row94_col3, #T_f1040_row163_col3, #T_f1040_row240_col3, #T_f1040_row273_col3, #T_f1040_row382_col3, #T_f1040_row421_col3, #T_f1040_row508_col3, #T_f1040_row660_col3 {
#   background-color: rgba(174, 9, 38, 0.7);
# }
# #T_f1040_row7_col3, #T_f1040_row32_col3, #T_f1040_row117_col3, #T_f1040_row173_col3, #T_f1040_row178_col3, #T_f1040_row258_col3, #T_f1040_row301_col3, #T_f1040_row438_col3, #T_f1040_row479_col3, #T_f1040_row489_col3, #T_f1040_row538_col3, #T_f1040_row570_col3, #T_f1040_row576_col3, #T_f1040_row641_col3, #T_f1040_row657_col3, #T_f1040_row659_col3, #T_f1040_row692_col3, #T_f1040_row710_col3 {
#   background-color: rgba(253, 190, 110, 0.7);
# }
# #T_f1040_row8_col3, #T_f1040_row13_col3, #T_f1040_row30_col3, #T_f1040_row348_col3, #T_f1040_row540_col3, #T_f1040_row543_col3 {
#   background-color: rgba(234, 89, 58, 0.7);
# }
# #T_f1040_row9_col3, #T_f1040_row48_col3, #T_f1040_row137_col3, #T_f1040_row147_col3, #T_f1040_row357_col3, #T_f1040_row487_col3, #T_f1040_row548_col3, #T_f1040_row597_col3, #T_f1040_row678_col3, #T_f1040_row694_col3 {
#   background-color: rgba(186, 20, 38, 0.7);
# }
# #T_f1040_row10_col3, #T_f1040_row156_col3, #T_f1040_row216_col3, #T_f1040_row388_col3, #T_f1040_row520_col3 {
#   background-color: rgba(149, 209, 104, 0.7);
# }
# #T_f1040_row11_col3, #T_f1040_row70_col3, #T_f1040_row88_col3, #T_f1040_row103_col3, #T_f1040_row302_col3, #T_f1040_row326_col3, #T_f1040_row354_col3, #T_f1040_row491_col3, #T_f1040_row506_col3, #T_f1040_row525_col3, #T_f1040_row539_col3, #T_f1040_row577_col3, #T_f1040_row608_col3, #T_f1040_row670_col3, #T_f1040_row701_col3 {
#   background-color: rgba(247, 137, 79, 0.7);
# }
# #T_f1040_row12_col3, #T_f1040_row322_col3, #T_f1040_row419_col3, #T_f1040_row443_col3, #T_f1040_row457_col3, #T_f1040_row460_col3, #T_f1040_row482_col3, #T_f1040_row560_col3, #T_f1040_row632_col3, #T_f1040_row643_col3, #T_f1040_row645_col3, #T_f1040_row648_col3, #T_f1040_row667_col3, #T_f1040_row709_col3 {
#   background-color: rgba(254, 250, 183, 0.7);
# }
# #T_f1040_row14_col3, #T_f1040_row392_col3 {
#   background-color: rgba(173, 220, 110, 0.7);
# }
# #T_f1040_row16_col3, #T_f1040_row172_col3, #T_f1040_row255_col3, #T_f1040_row264_col3, #T_f1040_row318_col3, #T_f1040_row352_col3, #T_f1040_row504_col3, #T_f1040_row530_col3, #T_f1040_row532_col3, #T_f1040_row547_col3, #T_f1040_row591_col3, #T_f1040_row596_col3, #T_f1040_row634_col3, #T_f1040_row638_col3, #T_f1040_row642_col3, #T_f1040_row653_col3, #T_f1040_row693_col3 {
#   background-color: rgba(253, 216, 132, 0.7);
# }
# #T_f1040_row18_col3, #T_f1040_row76_col3, #T_f1040_row77_col3, #T_f1040_row160_col3, #T_f1040_row327_col3, #T_f1040_row333_col3, #T_f1040_row359_col3, #T_f1040_row369_col3, #T_f1040_row379_col3, #T_f1040_row411_col3, #T_f1040_row456_col3, #T_f1040_row485_col3, #T_f1040_row574_col3, #T_f1040_row605_col3, #T_f1040_row637_col3 {
#   background-color: rgba(254, 231, 151, 0.7);
# }
# #T_f1040_row19_col3, #T_f1040_row283_col3, #T_f1040_row546_col3, #T_f1040_row663_col3, #T_f1040_row700_col3 {
#   background-color: rgba(238, 97, 61, 0.7);
# }
# #T_f1040_row20_col3, #T_f1040_row26_col3, #T_f1040_row63_col3, #T_f1040_row78_col3, #T_f1040_row82_col3, #T_f1040_row135_col3, #T_f1040_row159_col3, #T_f1040_row226_col3, #T_f1040_row250_col3, #T_f1040_row275_col3, #T_f1040_row285_col3, #T_f1040_row314_col3, #T_f1040_row321_col3, #T_f1040_row325_col3, #T_f1040_row339_col3, #T_f1040_row341_col3, #T_f1040_row344_col3, #T_f1040_row356_col3, #T_f1040_row404_col3, #T_f1040_row446_col3, #T_f1040_row502_col3, #T_f1040_row603_col3, #T_f1040_row677_col3, #T_f1040_row699_col3, #T_f1040_row707_col3 {
#   background-color: rgba(253, 196, 115, 0.7);
# }
# #T_f1040_row21_col3, #T_f1040_row191_col3, #T_f1040_row436_col3, #T_f1040_row627_col3 {
#   background-color: rgba(212, 45, 38, 0.7);
# }
# #T_f1040_row23_col3, #T_f1040_row34_col3, #T_f1040_row50_col3, #T_f1040_row108_col3, #T_f1040_row114_col3, #T_f1040_row116_col3, #T_f1040_row152_col3, #T_f1040_row153_col3, #T_f1040_row182_col3, #T_f1040_row192_col3, #T_f1040_row228_col3, #T_f1040_row235_col3, #T_f1040_row242_col3, #T_f1040_row297_col3, #T_f1040_row303_col3, #T_f1040_row342_col3, #T_f1040_row434_col3, #T_f1040_row448_col3, #T_f1040_row455_col3, #T_f1040_row511_col3, #T_f1040_row544_col3, #T_f1040_row568_col3, #T_f1040_row595_col3, #T_f1040_row702_col3, #T_f1040_row711_col3 {
#   background-color: rgba(246, 129, 76, 0.7);
# }
# #T_f1040_row24_col3, #T_f1040_row31_col3, #T_f1040_row124_col3, #T_f1040_row129_col3, #T_f1040_row149_col3, #T_f1040_row167_col3, #T_f1040_row212_col3, #T_f1040_row256_col3, #T_f1040_row279_col3, #T_f1040_row288_col3, #T_f1040_row417_col3, #T_f1040_row445_col3, #T_f1040_row481_col3, #T_f1040_row522_col3, #T_f1040_row529_col3 {
#   background-color: rgba(254, 254, 189, 0.7);
# }
# #T_f1040_row25_col3 {
#   background-color: rgba(84, 180, 94, 0.7);
# }
# #T_f1040_row27_col3, #T_f1040_row120_col3, #T_f1040_row157_col3, #T_f1040_row174_col3, #T_f1040_row232_col3, #T_f1040_row281_col3, #T_f1040_row304_col3, #T_f1040_row345_col3, #T_f1040_row490_col3, #T_f1040_row554_col3, #T_f1040_row562_col3, #T_f1040_row675_col3, #T_f1040_row691_col3 {
#   background-color: rgba(246, 251, 179, 0.7);
# }
# #T_f1040_row28_col3, #T_f1040_row37_col3, #T_f1040_row41_col3, #T_f1040_row55_col3, #T_f1040_row79_col3, #T_f1040_row83_col3, #T_f1040_row90_col3, #T_f1040_row95_col3, #T_f1040_row139_col3, #T_f1040_row313_col3, #T_f1040_row324_col3, #T_f1040_row330_col3, #T_f1040_row337_col3, #T_f1040_row349_col3, #T_f1040_row391_col3, #T_f1040_row394_col3, #T_f1040_row399_col3, #T_f1040_row492_col3, #T_f1040_row493_col3, #T_f1040_row496_col3, #T_f1040_row515_col3, #T_f1040_row589_col3, #T_f1040_row668_col3, #T_f1040_row688_col3 {
#   background-color: rgba(249, 147, 84, 0.7);
# }
# #T_f1040_row29_col3, #T_f1040_row35_col3, #T_f1040_row115_col3, #T_f1040_row141_col3, #T_f1040_row162_col3, #T_f1040_row184_col3, #T_f1040_row248_col3, #T_f1040_row296_col3, #T_f1040_row308_col3, #T_f104
