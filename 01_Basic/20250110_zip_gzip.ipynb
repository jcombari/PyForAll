# %% [markdown]
# # 🐼 Python-Pandas: Analyze ZIP Files Without Extracting Them 🌟
#
# 🔎 Did you know Pandas can read compressed files directly?
# Imagine working with massive datasets stored in **ZIP** files and processing them without extracting. This saves time, storage, and helps you manage data like a pro! 🚀
#
# ## 💡 Real-world example:
# - 👉 Simulate a ZIP file containing **Titanic** data (survivors, classes, genders, etc.).
# - 👉 Use **Pandas** to process it directly from the ZIP.
# - 👉 Analyze survival rates by class and gender, and visualize it in a chart.
#
# ## ✨ Why does it matter?
# Working with compressed data is essential when handling large volumes in **Machine Learning** projects, financial systems, or digital platforms. Plus, it’s efficient and modern! 🌍
#
# ## 📊 Outcome
# Multivariate analyses like this help you uncover critical patterns, such as factors influencing survival in disasters, predictive models, and more. Level up your skills!
#
# ## 🧪 **How would you apply it?**
# Explore this example and let me know how you’d use this technique in your work. 🚀
#
# 🌍 Because technology should be accessible to everyone.
#
# ### [GitHub Repository: PyForAll](https://github.com/jcombari/PyForAll)
#
#
# ---
#
# # 🐼 Python-Pandas: Analiza archivos ZIP sin descomprimirlos 🌟
#
# 🔎 ¿Sabías que Pandas puede leer archivos comprimidos directamente?
# Imagina trabajar con enormes datasets almacenados en archivos **ZIP** y procesarlos sin descomprimirlos. ¡Esto ahorra tiempo y almacenamiento, mientras te ayuda a manejar datos masivos como un profesional! 🚀
#
# ## 💡 Caso práctico:
# - 👉 Simularemos un archivo ZIP que contiene datos del **Titanic** (sobrevivientes, clases, géneros, etc.).
# - 👉 Usaremos **Pandas** para procesarlo directamente desde el ZIP.
# - 👉 Analizaremos tasas de supervivencia por clase y género, y lo visualizaremos en un gráfico.
#
# ## ✨ ¿Por qué importa?
# Trabajar con datos comprimidos es esencial cuando manejas grandes volúmenes de datos en proyectos de **Machine Learning**, sistemas financieros o plataformas digitales. Además, ¡es eficiente y moderno! 🌍
#
# ## 📊 Resultado
# Los análisis multivariantes como este te permiten descubrir patrones cruciales, como qué factores influyen en la supervivencia en desastres, modelos predictivos, y más. ¡Llevarás tus habilidades al siguiente nivel!
#
# ##  🧪 **¿Cómo lo aplicarías?**
# Explora este ejemplo y coméntame cómo usarías esta técnica en tu día a día. 🚀
#
# 🌍 Porque la tecnología debe ser accesible para todos.
#
# ### [Repositorio GitHub: PyForAll](https://github.com/jcombari/PyForAll)

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import zipfile
import io
import matplotlib.pyplot as plt

# Load the Titanic dataset from seaborn
titanic = sns.load_dataset('titanic')

# Save the dataset as a CSV inside a ZIP file (simulate data source)
buffer = io.BytesIO()
with zipfile.ZipFile(buffer, 'w', zipfile.ZIP_DEFLATED) as zf:
    zf.writestr("titanic.csv", titanic.to_csv(index=False))

# Reset the buffer's position
buffer.seek(0)

# Read the dataset directly from the ZIP file
with zipfile.ZipFile(buffer) as zf:
    with zf.open("titanic.csv") as file:
        df = pd.read_csv(file)

# Display the first few rows of the dataset
print("Dataset Preview:")
print(df.head())

# Grouping example: Analyzing survival rate by class and gender
grouped = df.groupby(['pclass', 'sex'])['survived'].mean()

# Print the grouped data
print("\nSurvival Rate by Class and Gender:")
print(grouped)

# Visualize the data
grouped.unstack().plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title("Survival Rate by Class and Gender")
plt.ylabel("Survival Rate")
plt.xlabel("Passenger Class")
plt.legend(title="Gender")
plt.show()
# Out:
# Dataset Preview:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# Survival Rate by Class and Gender:
# pclass  sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
# ...
