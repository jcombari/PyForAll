# %% [markdown]
# # English Version
#
# ## 🐍🐼 Python-Pandas: Boost Your Analysis with pd.Categorical
#
# ❓ Did you know optimizing columns with categorical data can revolutionize your data analysis?
# Working with large datasets can be challenging, but converting columns to categories can make your analysis faster, more efficient, and clearer.
#
# ## 📊 Key Benefits of pd.Categorical:
# - 🌈 Segment customers and uncover hidden patterns.
# - 🚀 Optimize complex calculations in nested groupings.
# - 💾 Reduce memory usage and improve performance.
#
# ## 🚀 Practical Example: Discovering Patterns in the Titanic
# We’ll use the Titanic dataset from the seaborn library. We'll explore grouping passengers by class, gender, and survival while leveraging pd.Categorical advantages.
#
# ## 🔍 Business Impact:
# - Identify survival patterns across key groups.
# - Inspire data-driven strategies for effective resource allocation.
#
# ## 🎨 Interactive Visualization:
# We include a chart showing survival distribution by class and gender.
#
# Do you already use pd.Categorical in your projects? 🌍💻 Share your thoughts 👇
#
# [GitHub - PyForAll](https://github.com/jcombari/PyForAll)
#
#  🌍✨ #DataScience #Python #Pandas #AI #MachineLearning #DeepLearning #DataAnalysis #DataVisualization
#
# ---
#
# # 🐍🐼 Python-Pandas: Impulsa tu análisis con pd.Categorical
#
# ❓ ¿Sabías que optimizar tus columnas con datos categóricos puede revolucionar tu análisis de datos?
# Trabajar con datasets grandes puede ser complicado, pero convertir columnas a categorías puede hacer tu análisis más rápido, eficiente y claro.
#
# ## 📊 Beneficios clave de pd.Categorical:
# - 🌈 Segmentar clientes y descubrir patrones ocultos.
# - 🚀 Optimizar cálculos complejos en agrupaciones anidadas.
# - 💾 Reducir el uso de memoria y mejorar el rendimiento.
#
# ## 🚀 Ejemplo práctico: Descubriendo patrones en el Titanic
# Usaremos el dataset "Titanic" de la librería seaborn. Exploraremos cómo agrupar pasajeros por clase, género y supervivencia, aprovechando las ventajas de pd.Categorical.
#
# ## 🔍 Impacto en el negocio:
# - Identificar patrones de supervivencia según grupos clave.
# - Inspirar estrategias basadas en datos para asignar recursos de manera efectiva.
#
# ## 🎨 Visualización interactiva:
# Incluimos un gráfico que muestra la distribución de la supervivencia por clase y género.
#
# ¿Ya usas pd.Categorical en tus proyectos? 🌍💻 Comparte tus experiencias 👇
#
# [GitHub - PyForAll](https://github.com/jcombari/PyForAll)
#
#  🌍✨ #DataScience #Python #Pandas #AI #MachineLearning #DeepLearning #DataAnalysis #DataVisualization

# %%
# Importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic = sns.load_dataset("titanic")

# Overview of the dataset
print("Dataset Overview:")
print(titanic.head())

# Converting specific columns to categorical types
titanic["class"] = pd.Categorical(titanic["class"], categories=["Third", "Second", "First"], ordered=True)
titanic["sex"] = pd.Categorical(titanic["sex"])
titanic["survived"] = pd.Categorical(titanic["survived"], categories=[0, 1], ordered=True)

# Memory usage before and after conversion
print("\nMemory Usage Before and After Conversion:")
print(titanic.info(memory_usage="deep"))

# Grouping by class, sex, and survival status
grouped = titanic.groupby(["class", "sex", "survived"], observed=False).size().reset_index(name="count")

# Display grouped data
print("\nGrouped Data:")
print(grouped)

# Preparing labels for the plot by concatenating class and gender
grouped["label"] = grouped["class"].astype(str) + " - " + grouped["sex"].astype(str)

# Plotting the data
plt.figure(figsize=(8, 6))
for survival_status in grouped["survived"].cat.categories:
    subset = grouped[grouped["survived"] == survival_status]
    plt.bar(subset["label"], subset["count"], label=f"Survived: {survival_status}")

plt.title("Survival Counts by Class and Gender")
plt.xlabel("Class and Gender")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.legend(title="Survival Status")
plt.tight_layout()
plt.show()
# Out:
# Dataset Overview:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# Memory Usage Before and After Conversion:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ...
