# %% [markdown]
# # 🐍🐼 Python-Pandas: Group and classify with style using `groupby` + `pd.cut`!
#
# Did you know you can turn raw data into valuable insights by categorizing it into specific groups? 🚀 Imagine segmenting your customers by age within each region and calculating unique statistics for each group. This approach not only personalizes your analysis but also helps make more strategic decisions.
#
# ### ✨ How does it work?
# 🔹 `groupby`: Allows you to group data based on one or more columns.
# 🔹 `pd.cut`: Turns continuous columns (like ages or income) into predefined categories.
#
# ### 📊 Practical example:
# Let’s say you have user data with information about age and region. You can:
# ✅ Split ages into ranges (young, adult, senior).
# ✅ Calculate the average income for each range in each region.
# ✅ Visualize it all in a clear chart that highlights patterns.
#
# ### 💡 Business impact:
# This analysis helps identify key patterns in different demographic segments and optimize marketing or resource allocation strategies.
#
# ### ❓ Reflection:
# How could you use this technique to improve your daily decisions?
#
# #DataScience #Python #Pandas #MachineLearning #AI #DataAnalytics
#
# ---
#
# # 🐍🐼 Python-Pandas: ¡Agrupa y clasifica con estilo usando `groupby` + `pd.cut`!
#
# ¿Sabías que puedes convertir datos crudos en insights valiosos clasificándolos en categorías específicas? 🚀 Imagina poder segmentar a tus clientes por edad dentro de cada región y calcular estadísticas únicas para cada grupo. Este enfoque no solo personaliza tus análisis, sino que también puede ayudarte a tomar decisiones más estratégicas.
#
# ### ✨ ¿Cómo funciona?
# 🔹 `groupby`: Nos permite agrupar los datos según una o más columnas.
# 🔹 `pd.cut`: Convierte columnas continuas (como edades o ingresos) en categorías definidas.
#
# ### 📊 Ejemplo práctico:
# Supongamos que tienes datos de usuarios con información sobre su edad y región. Puedes:
# ✅ Dividir las edades en rangos (joven, adulto, senior).
# ✅ Calcular el promedio de ingresos para cada rango en cada región.
# ✅ Visualizar todo en un gráfico claro que destaque los patrones.
#
# ### 💡 Impacto en negocios:
# Este análisis permite identificar patrones clave en diferentes segmentos demográficos y optimizar estrategias de marketing o distribución de recursos.
#
# ### ❓ Reflexión:
# ¿Cómo podrías usar esta técnica para mejorar tus decisiones diarias?
#
# #DataScience #Python #Pandas #MachineLearning #AI #DataAnalytics

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Generate a sample dataset
np.random.seed(42)
data = {
    'Region': np.random.choice(['North', 'South', 'East', 'West'], size=200),
    'Age': np.random.randint(18, 70, size=200),
    'Income': np.random.randint(20000, 80000, size=200)
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Categorizing age into groups using pd.cut
age_bins = [0, 30, 50, 70]
age_labels = ['Young', 'Adult', 'Senior']
df['Age_Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

# Grouping data by Region and Age_Group, calculating mean income
grouped = df.groupby(['Region', 'Age_Group'], observed=False)['Income'].mean().reset_index()


# Visualizing the data
plt.figure(figsize=(10, 6))
for region in grouped['Region'].unique():
    subset = grouped[grouped['Region'] == region]
    plt.plot(subset['Age_Group'], subset['Income'], marker='o', label=region)

# Adding plot details
plt.title('Average Income by Age Group and Region', fontsize=14)
plt.xlabel('Age Group', fontsize=12)
plt.ylabel('Average Income', fontsize=12)
plt.legend(title='Region')
plt.grid(alpha=0.5)
plt.show()

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Generate a sample dataset
np.random.seed(42)
data = {
    'Region': np.random.choice(['North', 'South', 'East', 'West'], size=200),
    'Age': np.random.randint(18, 70, size=200),
    'Income': np.random.randint(20000, 80000, size=200)
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Categorizing age into groups using pd.cut
age_bins = [0, 30, 50, 70]
age_labels = ['Young', 'Adult', 'Senior']
df['Age_Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

# Grouping data by Region and Age_Group, calculating mean income
grouped = df.groupby(['Region', 'Age_Group'])['Income'].mean().reset_index()

# Visualizing the data
plt.figure(figsize=(10, 6))
for region in grouped['Region'].unique():
    subset = grouped[grouped['Region'] == region]
    plt.plot(subset['Age_Group'], subset['Income'], marker='o', label=region)

# Adding plot details
plt.title('Average Income by Age Group and Region', fontsize=14)
plt.xlabel('Age Group', fontsize=12)
plt.ylabel('Average Income', fontsize=12)
plt.legend(title='Region')
plt.grid(alpha=0.5)
plt.show()
# Out:
# C:\Users\jenny\AppData\Local\Temp/ipykernel_15972/4253004977.py:23: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['Region', 'Age_Group'])['Income'].mean().reset_index()
